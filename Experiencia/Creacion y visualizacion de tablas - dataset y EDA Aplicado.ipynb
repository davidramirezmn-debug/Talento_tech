# %%
import pandas as pd
lista_nombres = ["Alexander","Alejandra","Dario", "Wilson", "Rosa", "David", "Francisco", "Irene", "Samara", "Gabriela", "Camila", "Sofia", "Diana", "Aixa", "Deisy","Teresa", "James", "Hugo", "Katherine","Jeronimo"]
lista_pesos = [69, 57, 64, 80 , 40, 82, 65, 87, 60, 35, 68, 48, 39, 60, 70, 65, 78, 75, 75, 25]
lista_alturas = [1.78, 1.60, 1.64, 1.71, 1.53, 1.78, 1.82, 1.68, 1.35, 1.68, 1.58, 1.27, 1.68, 1.57, 1.67, 1.56, 1.75, 1.78, 1.65, 0.90]
# convierte el dicc en undataframe (marco_de_datos=tabla=dataset=conjunto_de_datos)
dicc_datos = {"Nombre":lista_nombres, "Peso":lista_pesos, "Altura":lista_alturas}
df = pd.DataFrame(dicc_datos)
df
# Out:
#        Nombre  Peso  Altura
# 0   Alexander    69    1.78
# 1   Alejandra    57    1.60
# 2       Dario    64    1.64
# 3      Wilson    80    1.71
# 4        Rosa    40    1.53
# 5       David    82    1.78
# 6   Francisco    65    1.82
# 7       Irene    87    1.68
# 8      Samara    60    1.35
# 9    Gabriela    35    1.68
# 10     Camila    68    1.58
# 11      Sofia    48    1.27
# 12      Diana    39    1.68
# 13       Aixa    60    1.57
# 14      Deisy    70    1.67
# 15     Teresa    65    1.56
# 16      James    78    1.75
# 17       Hugo    75    1.78
# 18  Katherine    75    1.65
# 19   Jeronimo    25    0.90

# %%
df
# Out:
#        Nombre  Peso  Altura
# 0   Alexander    69    1.78
# 1   Alejandra    57    1.60
# 2       Dario    64    1.64
# 3      Wilson    80    1.71
# 4        Rosa    40    1.53
# 5       David    82    1.78
# 6   Francisco    65    1.82
# 7       Irene    87    1.68
# 8      Samara    60    1.35
# 9    Gabriela    35    1.68
# 10     Camila    68    1.58
# 11      Sofia    48    1.27
# 12      Diana    39    1.68
# 13       Aixa    60    1.57
# 14      Deisy    70    1.67
# 15     Teresa    65    1.56
# 16      James    78    1.75
# 17       Hugo    75    1.78
# 18  Katherine    75    1.65
# 19   Jeronimo    25    0.90

# %%
df
# Out:
#        Nombre  Peso  Altura
# 0   Alexander    69    1.78
# 1   Alejandra    57    1.60
# 2       Dario    64    1.64
# 3      Wilson    80    1.71
# 4        Rosa    40    1.53
# 5       David    82    1.78
# 6   Francisco    65    1.82
# 7       Irene    87    1.68
# 8      Samara    60    1.35
# 9    Gabriela    35    1.68
# 10     Camila    68    1.58
# 11      Sofia    48    1.27
# 12      Diana    39    1.68
# 13       Aixa    60    1.57
# 14      Deisy    70    1.67
# 15     Teresa    65    1.56
# 16      James    78    1.75
# 17       Hugo    75    1.78
# 18  Katherine    75    1.65
# 19   Jeronimo    25    0.90

# %%
df
# Out:
#        Nombre  Peso  Altura
# 0   Alexander    69    1.78
# 1   Alejandra    57    1.60
# 2       Dario    64    1.64
# 3      Wilson    80    1.71
# 4        Rosa    40    1.53
# 5       David    82    1.78
# 6   Francisco    65    1.82
# 7       Irene    87    1.68
# 8      Samara    60    1.35
# 9    Gabriela    35    1.68
# 10     Camila    68    1.58
# 11      Sofia    48    1.27
# 12      Diana    39    1.68
# 13       Aixa    60    1.57
# 14      Deisy    70    1.67
# 15     Teresa    65    1.56
# 16      James    78    1.75
# 17       Hugo    75    1.78
# 18  Katherine    75    1.65
# 19   Jeronimo    25    0.90

# %%
import numpy as np
import random

# Generate 80 additional random data points
np.random.seed(42) # for reproducibility

# List of common Latin American first names
latin_american_names = [
    "Sofia", "Mateo", "Valentina", "Sebastian", "Isabella", "Leonardo", "Camila", "Gabriel", "Valeria", "Nicolas",
    "Daniela", "Alejandro", "Mariana", "Santiago", "Gabriela", "Manuel", "Victoria", "Diego", "Carolina", "Emiliano",
    "Lucia", "Benjamín", "Andrea", "Joaquín", "Paula", "Felipe", "Natalia", "Ignacio", "Alexandra", "Cristobal",
    "Martina", "Agustin", "Fernanda", "Miguel", "Florencia", "Alonso", "Emilia", "Bruno", "Catalina", "Antonio",
    "Josefa", "Agustin", "Isidora", "Vicente", "Antonia", "Maximiliano", "Francisca", "Tomas", "Javiera", "Martin",
    "Jose", "Trinidad", "Gonzalo", "Amanda", "Benjamin", "Paz", "Cristian", "Consuelo", "Esteban", "Constanza",
    "Diego", "Rocio", "Francisco", "Barbara", "Juan", "Monserrat", "Luis", "Jose", "Claudia", "Rodrigo",
    "Alejandra", "Mauricio", "Pilar", "Alfredo", "Bernardita", "Victor", "Daniela", "Patricio", "Ignacia", "Hernan"
]

# Shuffle the list of names
random.shuffle(latin_american_names)

additional_nombres = latin_american_names[:80]
# Generate weights as two-digit numbers
additional_pesos = np.random.randint(30, 99, 80).tolist()
# Generate heights in meters with two decimal places
additional_alturas = np.around(np.random.uniform(1.20, 1.90, 80), decimals=2).tolist()

# Create a new DataFrame with the additional data
additional_df = pd.DataFrame({
    "Nombre": additional_nombres,
    "Peso": additional_pesos,
    "Altura": additional_alturas
})

# Concatenate the original and additional DataFrames
# Reset index to ensure a continuous index after concatenation
df = pd.concat([df.iloc[:20], additional_df], ignore_index=True)


# Calculate BMI (Peso / Altura^2)
df['IMC'] = df['Peso'] / (df['Altura']**2)

# Define a function to classify BMI
def classify_bmi(imc):
    if imc < 18.5:
        return 'Bajo peso'
    elif 18.5 <= imc < 24.9:
        return 'Peso normal'
    elif 24.9 <= imc < 29.9:
        return 'Sobrepeso'
    else:
        return 'Obesidad'

# Apply the classification function to create the 'Clasificacion' column
df['Clasificacion'] = df['IMC'].apply(classify_bmi)

# Display the updated DataFrame
display(df)
# Out:
#        Nombre  Peso  Altura        IMC Clasificacion
# 0   Alexander    69    1.78  21.777553   Peso normal
# 1   Alejandra    57    1.60  22.265625   Peso normal
# 2       Dario    64    1.64  23.795360   Peso normal
# 3      Wilson    80    1.71  27.358845     Sobrepeso
# 4        Rosa    40    1.53  17.087445     Bajo peso
# ..        ...   ...     ...        ...           ...
# 95     Felipe    30    1.84   8.861059     Bajo peso
# 96    Gonzalo    37    1.37  19.713357   Peso normal
# 97  Valentina    92    1.30  54.437870      Obesidad
# 98    Gabriel    40    1.54  16.866251     Bajo peso
# 99    Barbara    37    1.89  10.358053     Bajo peso
#
# [100 rows x 5 columns]

# %%
df.describe()
# Out:
#              Peso      Altura         IMC
# count  100.000000  100.000000  100.000000
# mean    63.140000    1.549300   27.557610
# std     20.812302    0.207551   11.743275
# min     25.000000    0.900000    8.861059
# 25%     44.000000    1.395000   19.488745
# 50%     65.000000    1.560000   25.942477
# 75%     82.000000    1.730000   32.803781
# max     94.000000    1.890000   61.139479

# %%
df
# Out:
#        Nombre  Peso  Altura        IMC Clasificacion
# 0   Alexander    69    1.78  21.777553   Peso normal
# 1   Alejandra    57    1.60  22.265625   Peso normal
# 2       Dario    64    1.64  23.795360   Peso normal
# 3      Wilson    80    1.71  27.358845     Sobrepeso
# 4        Rosa    40    1.53  17.087445     Bajo peso
# ..        ...   ...     ...        ...           ...
# 95     Felipe    30    1.84   8.861059     Bajo peso
# 96    Gonzalo    37    1.37  19.713357   Peso normal
# 97  Valentina    92    1.30  54.437870      Obesidad
# 98    Gabriel    40    1.54  16.866251     Bajo peso
# 99    Barbara    37    1.89  10.358053     Bajo peso
#
# [100 rows x 5 columns]

# %%
display(df[['Nombre', 'Clasificacion']].describe())
# Out:
#            Nombre Clasificacion
# count         100           100
# unique         91             4
# top     Alejandra      Obesidad
# freq            2            35

# %%
display(df[['Nombre', 'Clasificacion']].value_counts())
# Out:
# Nombre     Clasificacion
# Agustin    Obesidad         2
# Jose       Bajo peso        2
# Gabriela   Bajo peso        2
# Aixa       Peso normal      1
# Alejandra  Peso normal      1
#                            ..
# Valeria    Peso normal      1
# Vicente    Obesidad         1
# Victor     Obesidad         1
# Victoria   Peso normal      1
# Wilson     Sobrepeso        1
# Name: count, Length: 97, dtype: int64

# %%
df[['Nombre', 'Clasificacion']].value_counts()
# Out:
# Nombre     Clasificacion
# Agustin    Obesidad         2
# Jose       Bajo peso        2
# Gabriela   Bajo peso        2
# Aixa       Peso normal      1
# Alejandra  Peso normal      1
#                            ..
# Valeria    Peso normal      1
# Vicente    Obesidad         1
# Victor     Obesidad         1
# Victoria   Peso normal      1
# Wilson     Sobrepeso        1
# Name: count, Length: 97, dtype: int64

# %%
df.describe()
# Out:
#              Peso      Altura         IMC
# count  100.000000  100.000000  100.000000
# mean    63.140000    1.549300   27.557610
# std     20.812302    0.207551   11.743275
# min     25.000000    0.900000    8.861059
# 25%     44.000000    1.395000   19.488745
# 50%     65.000000    1.560000   25.942477
# 75%     82.000000    1.730000   32.803781
# max     94.000000    1.890000   61.139479

# %%
df.describe(include='O')
# Out:
#            Nombre Clasificacion
# count         100           100
# unique         91             4
# top     Alejandra      Obesidad
# freq            2            35

# %%
df.describe(include='all')
# Out:
#            Nombre        Peso      Altura         IMC Clasificacion
# count         100  100.000000  100.000000  100.000000           100
# unique         91         NaN         NaN         NaN             4
# top     Alejandra         NaN         NaN         NaN      Obesidad
# freq            2         NaN         NaN         NaN            35
# mean          NaN   63.140000    1.549300   27.557610           NaN
# std           NaN   20.812302    0.207551   11.743275           NaN
# min           NaN   25.000000    0.900000    8.861059           NaN
# 25%           NaN   44.000000    1.395000   19.488745           NaN
# 50%           NaN   65.000000    1.560000   25.942477           NaN
# 75%           NaN   82.000000    1.730000   32.803781           NaN
# max           NaN   94.000000    1.890000   61.139479           NaN

# %% [markdown]
# ```
# # Esto tiene formato de código
# ```
# Pasos para realizar un EDA (Exploratory Data Analisys) - Analisis Exploratorio de Datos en google colabs - python.
#
#   1. Importación de las bibliotecas necesarias para EDA.
#   2. Carga de los datos en el marco de datos.
#   3. Comprobación de los tipos de datos.
#   4. Eliminar columnas irrelevantes
#   5. Cambiar el nombre de las columnas
#   6. Eliminar las filas duplicadas
#   7. Descartar los valores faltantes o nulos.
#   8. Detección de valores atípicos
#   9. Graficar diferentes características unas contra otras (dispersión), contra la frecuencia (histograma)

# %%
df
# Out:
#        Nombre  Peso  Altura        IMC Clasificacion
# 0   Alexander    69    1.78  21.777553   Peso normal
# 1   Alejandra    57    1.60  22.265625   Peso normal
# 2       Dario    64    1.64  23.795360   Peso normal
# 3      Wilson    80    1.71  27.358845     Sobrepeso
# 4        Rosa    40    1.53  17.087445     Bajo peso
# ..        ...   ...     ...        ...           ...
# 95     Felipe    30    1.84   8.861059     Bajo peso
# 96    Gonzalo    37    1.37  19.713357   Peso normal
# 97  Valentina    92    1.30  54.437870      Obesidad
# 98    Gabriel    40    1.54  16.866251     Bajo peso
# 99    Barbara    37    1.89  10.358053     Bajo peso
#
# [100 rows x 5 columns]

# %%
# Calculate the correlation matrix for the DataFrame df
correlation_matrix = df.corr(numeric_only=True)

# Display the correlation matrix
display(correlation_matrix)
# Out:
#             Peso    Altura       IMC
# Peso    1.000000  0.101253  0.722253
# Altura  0.101253  1.000000 -0.571778
# IMC     0.722253 -0.571778  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a heatmap of the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Mapa de Calor de la Matriz de Correlación')
plt.show()

# %%
df
# Out:
#        Nombre  Peso  Altura        IMC Clasificacion
# 0   Alexander    69    1.78  21.777553   Peso normal
# 1   Alejandra    57    1.60  22.265625   Peso normal
# 2       Dario    64    1.64  23.795360   Peso normal
# 3      Wilson    80    1.71  27.358845     Sobrepeso
# 4        Rosa    40    1.53  17.087445     Bajo peso
# ..        ...   ...     ...        ...           ...
# 95     Felipe    30    1.84   8.861059     Bajo peso
# 96    Gonzalo    37    1.37  19.713357   Peso normal
# 97  Valentina    92    1.30  54.437870      Obesidad
# 98    Gabriel    40    1.54  16.866251     Bajo peso
# 99    Barbara    37    1.89  10.358053     Bajo peso
#
# [100 rows x 5 columns]

# %% [markdown]
# # 3. Comprobación de los tipos de datos.

# %%
# Comprobar los tipos de datos de cada columna
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Nombre         100 non-null    object
#  1   Peso           100 non-null    int64
#  2   Altura         100 non-null    float64
#  3   IMC            100 non-null    float64
#  4   Clasificacion  100 non-null    object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 4.0+ KB
# None

# %% [markdown]
# # 4. Eliminar columnas irrelevantes (si las hubiera)
# # En este caso, todas las columnas son relevantes para el análisis de IMC.

# %% [markdown]
# # 5. Cambiar el nombre de las columnas (si fuera necesario)
# # Los nombres de las columnas son claros, no es necesario cambiarlos.

# %% [markdown]
# # 6. Eliminar las filas duplicadas

# %%
# Comprobar si hay filas duplicadas
filas_duplicadas = df.duplicated().sum()
print(f"Número de filas duplicadas: {filas_duplicadas}")

# Eliminar filas duplicadas (si las hay)
df = df.drop_duplicates()

# Comprobar de nuevo después de eliminar
filas_duplicadas_despues = df.duplicated().sum()
print(f"Número de filas duplicadas después de eliminar: {filas_duplicadas_despues}")
# Out:
# Número de filas duplicadas: 0
# Número de filas duplicadas después de eliminar: 0

# %% [markdown]
# # 7. Descartar los valores faltantes o nulos.

# %%
# Comprobar valores nulos por columna
display(df.isnull().sum())

# Si hubiera valores nulos y quisieras eliminarlos, usarías:
# df = df.dropna()
# Out:
# Nombre           0
# Peso             0
# Altura           0
# IMC              0
# Clasificacion    0
# dtype: int64

# %% [markdown]
# # 8. Detección de valores atípicos (Outliers)
# # Podemos visualizar los datos para identificar posibles valores atípicos en 'Peso', 'Altura' e 'IMC'.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Crear box plots para visualizar la distribución y los valores atípicos
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
sns.boxplot(y=df['Peso'])
plt.title('Box Plot de Peso')

plt.subplot(1, 3, 2)
sns.boxplot(y=df['Altura'])
plt.title('Box Plot de Altura')

plt.subplot(1, 3, 3)
sns.boxplot(y=df['IMC'])
plt.title('Box Plot de IMC')

plt.tight_layout()
plt.show()

# %% [markdown]
# # 9. Graficar diferentes características
# # Podemos usar histogramas para ver la distribución de 'Peso', 'Altura' e 'IMC', y gráficos de barras para la 'Clasificacion'.

# %%
# Histogramas para Peso, Altura e IMC
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
sns.histplot(df['Peso'], kde=True)
plt.title('Distribución de Peso')

plt.subplot(1, 3, 2)
sns.histplot(df['Altura'], kde=True)
plt.title('Distribución de Altura')

plt.subplot(1, 3, 3)
sns.histplot(df['IMC'], kde=True)
plt.title('Distribución de IMC')

plt.tight_layout()
plt.show()

# Gráfico de barras para la Clasificación
plt.figure(figsize=(8, 6))
sns.countplot(x=df['Clasificacion'])
plt.title('Distribución de Clasificación de IMC')
plt.xlabel('Clasificación')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# # Análisis de Correlación (Ya realizado en celdas anteriores, pero lo incluimos aquí como parte del EDA)
# # El mapa de calor mostrado anteriormente nos indica la relación entre las variables numéricas.

# %%
# Calcular y mostrar la matriz de correlación
correlation_matrix = df.corr(numeric_only=True)
display(correlation_matrix)

# Crear y mostrar el mapa de calor
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Mapa de Calor de la Matriz de Correlación')
plt.show()
# Out:
#             Peso    Altura       IMC
# Peso    1.000000  0.101253  0.722253
# Altura  0.101253  1.000000 -0.571778
# IMC     0.722253 -0.571778  1.000000

# %% [markdown]
# # Resumen estadístico de las columnas numéricas (Ya realizado, pero lo incluimos)

# %%
display(df.describe())
# Out:
#              Peso      Altura         IMC
# count  100.000000  100.000000  100.000000
# mean    63.140000    1.549300   27.557610
# std     20.812302    0.207551   11.743275
# min     25.000000    0.900000    8.861059
# 25%     44.000000    1.395000   19.488745
# 50%     65.000000    1.560000   25.942477
# 75%     82.000000    1.730000   32.803781
# max     94.000000    1.890000   61.139479

# %% [markdown]
# # Resumen estadístico de las columnas categóricas (Ya realizado, pero lo incluimos)

# %%
display(df.describe(include='O'))
# Out:
#            Nombre Clasificacion
# count         100           100
# unique         91             4
# top     Alejandra      Obesidad
# freq            2            35

# %% [markdown]
# # Resumen estadístico general (Ya realizado, pero lo incluimos)

# %%
display(df.describe(include='all'))
# Out:
#            Nombre        Peso      Altura         IMC Clasificacion
# count         100  100.000000  100.000000  100.000000           100
# unique         91         NaN         NaN         NaN             4
# top     Alejandra         NaN         NaN         NaN      Obesidad
# freq            2         NaN         NaN         NaN            35
# mean          NaN   63.140000    1.549300   27.557610           NaN
# std           NaN   20.812302    0.207551   11.743275           NaN
# min           NaN   25.000000    0.900000    8.861059           NaN
# 25%           NaN   44.000000    1.395000   19.488745           NaN
# 50%           NaN   65.000000    1.560000   25.942477           NaN
# 75%           NaN   82.000000    1.730000   32.803781           NaN
# max           NaN   94.000000    1.890000   61.139479           NaN

# %% [markdown]
# # 10. Finish task
# El EDA se ha completado, incluyendo la comprobación de tipos de datos, manejo de duplicados y nulos (aunque no había), visualización de distribuciones y detección de posibles atípicos, y análisis de correlación.

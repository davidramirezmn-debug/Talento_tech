# %% [markdown]
# # Importar librerias y Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder as labelencoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
df = pd.read_csv('https://raw.githubusercontent.com/pandas-dev/pandas/master/doc/data/titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # EDA listo

# %% [markdown]
# # Limpieza y procesamiento de datos

# %% [markdown]
# ##Duplicados

# %%
duplicados = df.duplicated().sum()
duplicados
# Out:
# np.int64(0)

# %%
duplicados_columnas = df[df.duplicated()]
duplicados_columnas
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
#Eliminar duplicados en dataset
#df.drop_duplicates()

# %% [markdown]
# ## Revision de Nulos

# %%
nulos = df.isnull().sum()
nulos
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
pct_nulos = df.isnull().mean()*100
pct_nulos
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %% [markdown]
# ## Imputacion de Datos

# %%
df_copy = df.copy()

# %%
df_copy.head(6)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q

# %%
# df_copy ["Age"] = df_copy["Age"].fillna( df_copy["Age"].median())
# Rellena los campos nulos (fillna) con la mediana - se usa para datos enteros grandes

# %%
df_copy = df.copy()

# %%
df_copy ["Age"] = df_copy["Age"].fillna(df_copy.groupby(["Pclass", "Sex"])["Age"].transform("median"))
#Rellena los campos nulos (fillna) con la mediana, agrupando las filas "Pclass" y "Sex" para calcularla - se usa para datos enteros grandes

# %%
df_copy.head(6)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male  25.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df_copy['Embarked'].mode()[0]
# Out:
# 'S'

# %%
df_copy['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df_copy['Embarked'] = df_copy['Embarked'].fillna(df_copy['Embarked'].mode()[0])
#Rellena los campos nulos (fillna) con la moda - se usa para datos categoricos

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ## Revision de Outliers

# %%
#outliers
Q1 = df_copy["Age"].quantile(0.25)
Q3 = df_copy["Age"].quantile(0.75)
IQR = Q3 - Q1

limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

outliers = df_copy[(df_copy["Age"] < limite_inferior) | (df_copy["Age"] > limite_superior)]
outliers
# Out:
#      PassengerId  Survived  Pclass  \
# 11            12         1       1
# 33            34         0       2
# 54            55         0       1
# 94            95         0       3
# 96            97         0       1
# 116          117         0       3
# 170          171         0       1
# 195          196         1       1
# 232          233         0       2
# 252          253         0       1
# 268          269         1       1
# 275          276         1       1
# 280          281         0       3
# 326          327         0       3
# 366          367         1       1
# 438          439         0       1
# 456          457         0       1
# 483          484         1       3
# 487          488         0       1
# 493          494         0       1
# 545          546         0       1
# 555          556         0       1
# 570          571         1       2
# 587          588         1       1
# 625          626         0       1
# 630          631         1       1
# 659          660         0       1
# 672          673         0       2
# 684          685         0       2
# 694          695         0       1
# 745          746         0       1
# 829          830         1       1
# 851          852         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 11                            Bonnell, Miss Elizabeth  female  58.0      0
# 33                              Wheadon, Mr. Edward H    male  66.0      0
#
# 745      1    WE/P 5735   71.0000          B22        S
# 829      0       113572   80.0000          B28        S
# 851      0       347060    7.7750          NaN        S

# %%
sns.boxplot(df_copy["Age"])
# Out:
# <Axes: ylabel='Age'>

# %%
# Z-score

df_zscore = df_copy.copy()
media  = df_zscore["Age"].mean()
desviacion_estandar = df_zscore["Age"].std()

df_zscore["z_score"] = (df_zscore["Age"] - media) / desviacion_estandar

outliers_zscore = df_zscore[df_zscore["z_score"].abs() > 3]
outliers_zscore
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked   z_score
# 96   male  71.0      0      0    PC 17754  34.6542    A5        C  3.148395
# 116  male  70.5      0      0      370369   7.7500   NaN        Q  3.110813
# 493  male  71.0      0      0    PC 17609  49.5042   NaN        C  3.148395
# 630  male  80.0      0      0       27042  30.0000   A23        S  3.824861
# 672  male  70.0      0      0  C.A. 24580  10.5000   NaN        S  3.073232
# 745  male  70.0      1      1   WE/P 5735  71.0000   B22        S  3.073232
# 851  male  74.0      0      0      347060   7.7750   NaN        S  3.373883

# %% [markdown]
# ## Normalizacion de Datos

# %%
scaler = MinMaxScaler()
df_copy["Age_scaled"] = scaler.fit_transform(df_copy[["Age"]])

# %%
df_copy
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                        Graham, Miss Margaret Edith  female  19.0      0
# 888            Johnston, Miss Catherine Helen "Carrie"  female  21.5      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  Age_scaled
# 0        0         A/5 21171   7.2500   NaN        S    0.271174
# 1        0          PC 17599  71.2833   C85        C    0.472229
# 2        0  STON/O2. 3101282   7.9250   NaN        S    0.321438
# 3        0            113803  53.1000  C123        S    0.434531
# 4        0            373450   8.0500   NaN        S    0.434531
# ..     ...               ...      ...   ...      ...         ...
# 886      0            211536  13.0000   NaN        S    0.334004
# 887      0            112053  30.0000   B42        S    0.233476
# 888      2        W./C. 6607  23.4500   NaN        S    0.264891
# 889      0            111369  30.0000  C148        C    0.321438
# 890      0            370376   7.7500   NaN        Q    0.396833
#
# [891 rows x 13 columns]

# %% [markdown]
# ## Codificacion de categorias

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     891 non-null    object
#  12  Age_scaled   891 non-null    float64
# dtypes: float64(3), int64(5), object(5)
# memory usage: 90.6+ KB

# %%
df_copy['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df_dummies = df_copy.copy()

# %%
df_dummies = pd.get_dummies(df_dummies, columns=['Sex'])
df_dummies
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                                Heikkinen, Miss Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# ..                                                 ...   ...    ...    ...
# 886                              Montvila, Rev. Juozas  27.0      0      0
# 887                        Graham, Miss Margaret Edith  19.0      0      0
# 888            Johnston, Miss Catherine Helen "Carrie"  21.5      1      2
# 889                              Behr, Mr. Karl Howell  26.0      0      0
# 890                                Dooley, Mr. Patrick  32.0      0      0
#
#                Ticket     Fare Cabin Embarked  Age_scaled  Sex_female  \
# 0           A/5 21171   7.2500   NaN        S    0.271174       False
# 1            PC 17599  71.2833   C85        C    0.472229        True
# 2    STON/O2. 3101282   7.9250   NaN        S    0.321438        True
# 3              113803  53.1000  C123        S    0.434531        True
# 4              373450   8.0500   NaN        S    0.434531       False
# ..                ...      ...   ...      ...         ...         ...
# 886            211536  13.0000   NaN        S    0.334004       False
# 887            112053  30.0000   B42        S    0.233476        True
# 888        W./C. 6607  23.4500   NaN        S    0.264891        True
# 889            111369  30.0000  C148        C    0.321438       False
# 890            370376   7.7500   NaN        Q    0.396833       False
#
#      Sex_male
# 0        True
# 1       False
# 2       False
# 3       False
# 4        True
# ..        ...
# 886      True
# 887     False
# 888     False
# 889      True
# 890      True
#
# [891 rows x 14 columns]

# %%
df_dummies = df_copy.copy()

# %%
df_dummies = pd.get_dummies(df_dummies, columns=['Sex'], drop_first=True)
df_dummies
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                                Heikkinen, Miss Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# ..                                                 ...   ...    ...    ...
# 886                              Montvila, Rev. Juozas  27.0      0      0
# 887                        Graham, Miss Margaret Edith  19.0      0      0
# 888            Johnston, Miss Catherine Helen "Carrie"  21.5      1      2
# 889                              Behr, Mr. Karl Howell  26.0      0      0
# 890                                Dooley, Mr. Patrick  32.0      0      0
#
#                Ticket     Fare Cabin Embarked  Age_scaled  Sex_male
# 0           A/5 21171   7.2500   NaN        S    0.271174      True
# 1            PC 17599  71.2833   C85        C    0.472229     False
# 2    STON/O2. 3101282   7.9250   NaN        S    0.321438     False
# 3              113803  53.1000  C123        S    0.434531     False
# 4              373450   8.0500   NaN        S    0.434531      True
# ..                ...      ...   ...      ...         ...       ...
# 886            211536  13.0000   NaN        S    0.334004      True
# 887            112053  30.0000   B42        S    0.233476     False
# 888        W./C. 6607  23.4500   NaN        S    0.264891     False
# 889            111369  30.0000  C148        C    0.321438      True
# 890            370376   7.7500   NaN        Q    0.396833      True
#
# [891 rows x 13 columns]

# %%
df_label = df_copy.copy()

# %%
label = labelencoder()
df_label['Sex_label'] = label.fit_transform(df_label['Sex'])
df_label
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                        Graham, Miss Margaret Edith  female  19.0      0
# 888            Johnston, Miss Catherine Helen "Carrie"  female  21.5      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  Age_scaled  Sex_label
# 0        0         A/5 21171   7.2500   NaN        S    0.271174          1
# 1        0          PC 17599  71.2833   C85        C    0.472229          0
# 2        0  STON/O2. 3101282   7.9250   NaN        S    0.321438          0
# 3        0            113803  53.1000  C123        S    0.434531          0
# 4        0            373450   8.0500   NaN        S    0.434531          1
# ..     ...               ...      ...   ...      ...         ...        ...
# 886      0            211536  13.0000   NaN        S    0.334004          1
# 887      0            112053  30.0000   B42        S    0.233476          0
# 888      2        W./C. 6607  23.4500   NaN        S    0.264891          0
# 889      0            111369  30.0000  C148        C    0.321438          1
# 890      0            370376   7.7500   NaN        Q    0.396833          1
#
# [891 rows x 14 columns]

# %%
label = labelencoder()
df_label['Embarked_label'] = label.fit_transform(df_label['Embarked'])
df_label
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                        Graham, Miss Margaret Edith  female  19.0      0
# 888            Johnston, Miss Catherine Helen "Carrie"  female  21.5      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  Age_scaled  Sex_label  \
# 0        0         A/5 21171   7.2500   NaN        S    0.271174          1
# 1        0          PC 17599  71.2833   C85        C    0.472229          0
# 2        0  STON/O2. 3101282   7.9250   NaN        S    0.321438          0
# 3        0            113803  53.1000  C123        S    0.434531          0
# 4        0            373450   8.0500   NaN        S    0.434531          1
# ..     ...               ...      ...   ...      ...         ...        ...
# 886      0            211536  13.0000   NaN        S    0.334004          1
# 887      0            112053  30.0000   B42        S    0.233476          0
# 888      2        W./C. 6607  23.4500   NaN        S    0.264891          0
# 889      0            111369  30.0000  C148        C    0.321438          1
# 890      0            370376   7.7500   NaN        Q    0.396833          1
#
#      Embarked_label
# 0                 2
# 1                 0
# 2                 2
# 3                 2
# 4                 2
# ..              ...
# 886               2
# 887               2
# 888               2
# 889               0
# 890               1
#
# [891 rows x 15 columns]

# %%
df_label.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   PassengerId     891 non-null    int64
#  1   Survived        891 non-null    int64
#  2   Pclass          891 non-null    int64
#  3   Name            891 non-null    object
#  4   Sex             891 non-null    object
#  5   Age             891 non-null    float64
#  6   SibSp           891 non-null    int64
#  7   Parch           891 non-null    int64
#  8   Ticket          891 non-null    object
#  9   Fare            891 non-null    float64
#  10  Cabin           204 non-null    object
#  11  Embarked        891 non-null    object
#  12  Age_scaled      891 non-null    float64
#  13  Sex_label       891 non-null    int64
#  14  Embarked_label  891 non-null    int64
# dtypes: float64(3), int64(7), object(5)
# memory usage: 104.5+ KB

# %%
df_final = df_label[['Pclass','Age_scaled','SibSp','Embarked_label','Fare']]

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Pclass          891 non-null    int64
#  1   Age_scaled      891 non-null    float64
#  2   SibSp           891 non-null    int64
#  3   Embarked_label  891 non-null    int64
#  4   Fare            891 non-null    float64
# dtypes: float64(2), int64(3)
# memory usage: 34.9 KB

# %% [markdown]
# ## Regresion Lineal

# %%
x = df_final.drop("Fare", axis=1)
y = df_final["Fare"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
#MAE
#R2 --- Debe ser un valor positivo cercano a 1. nunca debe ser igual a 1

# %%
linear_model = LinearRegression()
linear_model.fit(x_train, y_train)
y_pred = linear_model.predict(x_test)

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(mae,mse,r2)
# Out:
# 20.57125610011181 960.388280844687 0.3793654530164148

# %% [markdown]
# ## Arboles de decision

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# Entrenar árbol
tree = DecisionTreeRegressor(random_state=42, max_depth=4)  # puedes jugar con max_depth
tree.fit(x_train, y_train)

# Predicciones
y_pred_tree = tree.predict(x_test)

# %%
mae = mean_absolute_error(y_test, y_pred_tree)
mse = mean_squared_error(y_test, y_pred_tree)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred_tree)

print(f"MAE:  {mae:.2f}")
print(f"MSE:  {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R²:   {r2:.2f}")
# Out:
# MAE:  17.92
# MSE:  1204.09
# RMSE: 34.70
# R²:   0.22

# %% [markdown]
# # Regresion Logistica
